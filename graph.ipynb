# %%
import pandas as pd

with pd.HDFStore("./data/sum2.hdf5") as store:
    print(store)
    temp =store.get("consequence")
    #temp2 =store.get("testcase")
    """
    a= temp["time_start"].to_list()
    l =len(a)
    print(l)
    
    b =temp["time_end"].to_list()
    
    pre_temp = 0
    """
    dict = {}
    

    box = []
    
    temp = temp["calc"].to_list()
    print(len(temp))
    #temp2 = temp2["total"].to_list()
    print(temp)

# %%
calc_box = temp[3000:]

# %%
import pandas as pd

with pd.HDFStore("./data/sum.hdf5") as store:
    temp =store.get("timecase")
    dict = {}
    

    box = []
    #print(temp.columns)
    #temp = sorted(temp, reverse=True)
    temp = temp["time"].to_list()
    print(len(temp))
    #temp2 = temp2["total"].to_list()
    #temp = temp[-1000:]
# Out:
# 55151

# %%
times = temp
times = list(times)
dummy_box = []
for i in range(len(times)):
    try:
        dif = times[i+1]-times[i]
    except:
        pass
    dummy_box.append(dif)

# %%
a = sorted(dummy_box,reverse=True)

# %%
a[-1]
# Out:
# 0.018168500000683707

# %%
for i,j in enumerate(calc_box):
    if j <= 177:
        print(i)
        break
# Out:
# 296

# %%
print(b)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
#topix_1976 = 435.1687223392232
# 434.3714486949468
#b = calc_box[297:]
c = dummy_box
a = range(len(c))
#b = map(lambda c: c*100/topix_1976 ,b)

"""
for i, j in enumerate(b):
    if j < 1913:
        b[i] = b[i-1]
        
    
"""
for i in range(len(c)):
    if c[i] <0 or c[i] > 1.5:
        c[i] = c[i-1]


plt.plot(a,c)
plt.ylim(0, 1)
plt.ylabel("executing time")
plt.show()

# %%
for i,j in enumerate(c):
    if c[i] - c[i-1] > 0.5:
        print(i)
# Out:
# 3543
# 3548
# 7879
# 7915
# 8108
# 8136
# 8173
# 10846
# 17597
# 18614
# 19295
# 37012
# 44065
# 44079
# 44718
# 44721
# 44742
# 45000
# 45318
# 45328

# %%
b = list(map(float,temp[3900:]))
a = range(len(b))
plt.plot(a,b)

plt.ylabel("topix")
plt.show()

# %%
print(temp)
# Out:
# ['   1892.66', '   1892.66', '   1892.66', '   1892.66', '   1892.66', '   1892.66', '   1892.66', '   1892.63', '   1892.64', '   1892.64', '   1892.64', '   1892.65', '   1892.68', '   1892.68', '   1892.68', '   1892.68', '   1892.65', '   1892.65', '   1892.65', '   1892.67', '   1892.67', '   1892.67', '   1892.69', '   1892.69', '   1892.69', '   1892.68', '   1892.68', '   1892.68', '   1892.68', '   1892.68', '   1892.68', '   1892.68', '   1892.68', '   1892.68', '   1892.68', '   1892.68', '   1892.68', '   1892.67', '   1892.67', '   1892.68', '   1892.68', '   1892.68', '   1892.68', '   1892.68', '   1892.68', '   1892.67', '   1892.67', '   1892.67', '   1892.69', '   1892.69', '   1892.69', '   1892.69', '   1892.69', '   1892.69', '   1892.70', '   1892.70', '   1892.70', '   1892.71', '   1892.71', '   1892.70', '   1892.70', '   1892.70', '   1892.71', '   1892.71', '   1892.71', '   1892.71', '   1892.71', '   1892.72', '   1892.72', '   1892.72', '   1892.70', '   1892.70', '   1892.70', '   1892.72', '   1892.72', '   1892.72', '   1892.72', '   1892.72', '   1
    if j < 1900 or j >1918:
        b.append(calc_box[i-1])
    elif b == "Nan":
        pass
    else:
        b.append(j)

# %%
print(b)

# %%
for i in range(1000):
    if float(temp[i]) < 7800 or float(temp[i]) > 9000:
        b[i] = temp[i-1]
plt.plot(a,b)
plt.ylim(6000, 9000)
plt.ylabel("calc")
plt.show()

# %%
print(d)

# %%
"""
for i in range(len(b)):
    if b[i] < 1840 or b[i] > 2000:
        b[i] = b[i-1]
"""
#b_plus20 = list(map(lambda a :a+20, b))
d = list(map(float,temp))
plt.plot(range(len(d)),d)
#plt.plot(range(len(c)),b_plus20)
plt.ylim(500, 2199)
plt.ylabel("topix")
plt.show()
#print(d)

# %%
a = range(len(b))
plt.plot(a,b)
plt.ylim(1870, 1890)
plt.ylabel("gotten_price")
plt.show()

# %%
checkbox = {}
for i, j in enumerate(b):
    checkbox[a[i]]= b[i]

# %%
count = 0 
array =[]
for i in range(21701):
    dummy =  checkbox.values()
    """
    
    
    if float(list(dummy)[i]) < 1860:
        array.append(i)
        count+= 1
    """

# %%
count = 0 
array =[]
for i in range(21701):
    dummy =  checkbox.values()
    if float(list(dummy)[i]) < 1860:
        array.append(i)
        count+= 1
for i in range(len(dummy)):
    if  i in array:
        elements = list(checkbox.items())
        #elements2 = list(checkbox.values())
        del elements[i] 

print(elements)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10852/3852224085.py in <module>
#       3 for i in range(21701):
#       4     dummy =  checkbox.values()
# ----> 5     if float(list(dummy)[i]) < 1860:
#       6         array.append(i)
#       7         count+= 1
#
# TypeError: float() argument must be a string or a number, not 'Timestamp'

# %%
dummy = map(float,temp)

# %%
from datetime import datetime
temp = list(map(datetime.timestamp,temp))

# %%
times = temp
times = list(times)
dummy_box = []
for i in range(len(times)):
    try:
        dif = times[i+1]-times[i]
    except:
        pass
    else:
        dummy_box.append(dif)
print(dummy_box)

# %%
#b = list(b)
"""
for i, j in enumerate(b):
    if j < 1913:
        b[i] = b[i-1]
        
    
"""
a = range(len(dummy_box))    

plt.plot(a,dummy_box)
plt.ylim(0, 50)
plt.ylabel("executing_time")
plt.show()

# %%
cabin = []
for i,j in enumerate(dummy_box):
    if j > 0.5:
        pass
    else:
        cabin.append(j)

print(cabin)

# %%
print(len(dummy_box))
# Out:
# 3295

# %%
plt.plot(range(len(cabin)),cabin)
plt.ylim(0, 0.6)
plt.ylabel("executing_time")
plt.show()

# %%
print(sorted(dummy_box,reverse=True))

# %%
len(checkbox.values())
# Out:
# 12275

# %%
new_count = 0
for i in range(len(dummy_box)):
    if dummy_box[i] >1 :
        new_count += 1
print(new_count)
# Out:
# 1425

# %%
with pd.HDFStore("./data/sum.hdf5") as store:
    temp = store.get("value")

dif = []
print(temp)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10028/2417324786.py in <module>
#       1 with pd.HDFStore("./data/sum.hdf5") as store:
# ----> 2     temp = store.get("value")
#       3
#       4 dif = []
#       5 print(temp)
#
# ~\anaconda3\lib\site-packages\pandas\io\pytables.py in get(self, key)
#     797             group = self.get_node(key)
#     798             if group is None:
# --> 799                 raise KeyError(f"No object named {key} in the file")
#     800             return self._read_group(group)
#     801
#
# KeyError: 'No object named value in the file'

# %%
print(dif)
del dif[0]

# %%
a = range(len(dif))
b = dif

plt.plot(a,b)
#plt.ylim(0, 0.6)
plt.ylabel("executing_time")
plt.show()

# %%
import time
d =temp["time"].tail(1)
print(d)
e =time.perf_counter()
# Out:
# 0    9951.186997
# Name: time, dtype: float64

# %%
(e-d) / 60
# Out:
# 0    129.760953
# Name: time, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
with pd.HDFStore("./data/sum2.hdf5") as store:
    value =store.get("consequence")
    #calc =store.get("calc")
    dict = {}
    

    box = []
    #print(temp.columns)
    #temp = sorted(temp, reverse=True)
    temp = value["topix"].to_list()
    calc = value["calc"].to_list()
    temp = list(map(float, temp))
    temp = temp[5000:]
    calc = calc[5000:]
    plt.plot(range(len(temp)), temp)
    plt.plot(range(len(temp)), calc)
    plt.show()
    #temp2 = temp2["total"].to_list()
    #temp = temp[-1000:]

# %%
with pd.HDFStore("./data/topix.hdf5") as store:
    value =store.get("key")
a = value["time"].to_list()
box = []
for i, j in enumerate(b):
    try:
        dif = b[i+1] - b[i]
    except:
        pass
    else:
        print(dif)
        box.append(dif)

# %%
box = sorted(box, reverse=False)

# %%
print(len(box))
# Out:
# 1216

# %%
count = 0
for i in box:
    if i < 1:
        count+= 1
print(count)
# Out:
# 458

# %%
import pandas as pd
with pd.HDFStore("./data/000_2.hdf5") as store:
    temp =store.get("classidx_0")

# %%
print(interval)
# Out:
# []

# %%
interval = []
a = temp["present"]
a[0].to_list()

# %%
b = list(a[0])

# %%
b[1]-b[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8424/360577383.py in <module>
# ----> 1 (b[1]-b[0]).astype(float)
#
# AttributeError: 'Timedelta' object has no attribute 'astype'

# %%
a

# %%
print(interval)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8236/2747937603.py in <module>
# ----> 1 print(interval)
#
# NameError: name 'interval' is not defined

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

a = range(len(dif))
plt.plot(a,dif)
plt.show()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

c = temp["total"].to_list()
a = range(len(c))
#b = map(lambda c: c*100/topix_1976 ,b)

"""
for i, j in enumerate(b):
    if j < 1913:
        b[i] = b[i-1]
        
    
"""



plt.plot(a,c)
plt.ylim(276, 287)
plt.ylabel("price")
plt.show()

# %%
for i,j in enumerate(temp["present"]):
    if i <8:
        print(j)
# Out:
# 1643.621288
# 1834.3146009999998
# 1862.1761300000007
# 1859.0492050000003
# 1859.1462769999998
# 2002.888332000001
# 2000.144798
# 2000.1248830000002

# %%
import pandas as pd
with pd.HDFStore("./data/378_2.hdf5") as store:
    temp = store.get("classidx_378")

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

count = 0
for i in temp:
    count += 1
    if count <= 3:
        continue
    
    c = temp[i].to_list()
    a = range(len(c))
    #b = map(lambda c: c*100/topix_1976 ,b)

    """
    for i, j in enumerate(b):
        if j < 1913:
            b[i] = b[i-1]
            
        
    """


    
    plt.plot(a,c)
    break
#plt.ylim(1970, 1987)
#plt.ylabel("price")
plt.show()

# %%
# %matplotlib inline

import matplotlib.pyplot as plt


c = temp["total"].to_list()
a = temp["present"].to_list()
    #b = map(lambda c: c*100/topix_1976 ,b)



    
plt.plot(a,c)

plt.ylim(95, 98)
#plt.ylabel("price")
plt.show()

# %%
a[-1]
# Out:
# Timestamp('2022-05-11 11:40:15.343455')

# %%
count = 0
for i in temp.keys():
    a = temp[i]
    for j,k in enumerate(a):
        if k == 0 and i != ("code_1413.T") and i != "code_1448.T" and i != "code_1768.T"and i != "code_1881.T":
            print(a.head(1), k)
# Out:
# 0    0.0
# Name: code_1352.T, dtype: float64 0.0
# 0    0.0
# Name: code_1375.T, dtype: float64 0.0
# 0    0.0
# Name: code_1376.T, dtype: float64 0.0
# 0    0.0
# Name: code_1377.T, dtype: float64 0.0
# 0    0.0
# Name: code_1963.T, dtype: float64 0.0

# %%
for i in temp["code_1413.T"]:
    if i != 0:
        print(i)

# %%
time = temp["present"]
c = time.to_list()

# %%
c[0]
# Out:
# Timestamp('2022-05-10 11:04:09.497411')

# %%
box = []
for i in range(len(c)):
    try:
        dif= c[i+1] - c[i]
    except:
        pass
    else:
        box.append(dif.microseconds*(10**(-6)))
box

# %%
for i in box:
    if i > 0.9:
        print(i)

# %%
b = b[1400:]

# %%
len(b)
# Out:
# 2294

# %%
for i,j in enumerate(b):
    if j < 90:
        c = temp["present"].to_list()
        print(c[i])

# %%
b = temp["total"].to_list()
a = range(len(b))
import matplotlib.pyplot as plt

plt.plot(a,b)
plt.ylim(100, 130)
plt.ylabel("price")
plt.show()

# %%
import pandas as pd
with pd.HDFStore("./data/sum2.hdf5") as store:
    temp = store.get("consequence")

# %%
b = temp["calc"].to_list()
b

# %%
a = temp["time"].to_list()
a

# %%
import matplotlib.pyplot as plt


    #b = map(lambda c: c*100/topix_1976 ,b)



    
plt.plot(a,b)
plt.xticks(color='w')
plt.ylim(1950, 2000)
plt.show()

# %%
d = temp["topix_etf"].to_list()
d
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\kose\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Users\kose\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\kose\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'topix_etf'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10744/22349103.py in <module>
# ----> 1 d = temp["topix_etf"].to_list()
#       2 d
#
# c:\Users\kose\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# c:\Users\kose\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'topix_etf'

# %%
import matplotlib.pyplot as plt


    #b = map(lambda c: c*100/topix_1976 ,b)



plt.plot(a,b,label="計算")   
plt.plot(a,c,label="実際")
plt.xticks(color='w')
plt.ylim(1930, 2000)
plt.legend()
plt.show()

# %%
c = list(map(float, c))

# %%
import datetime
for i in range(len(a)):
    if datetime.datetime.strptime(a[i],'%Y-%m-%d %H:%M:%S.%f').hour >= 11 and datetime.datetime.strptime(a[i],'%Y-%m-%d %H:%M:%S.%f').minute >=30:
        print(i, a[i])

# %%
a[700]
# Out:
# '2022-05-17 13:18:18.698654'

# %%
import matplotlib.pyplot as plt


    #b = map(lambda c: c*100/topix_1976 ,b)

a = a[16345:20000]
b = b[16345:20000]
c = c[16345:20000]
plt.plot(a,b,label="計算")   
plt.plot(a,c,label="実際")
#plt.xticks(color='w')
plt.ylim(1930, 2000)
plt.legend()
plt.show()
# Out:
# c:\Users\kose\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 35336 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\kose\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 31639 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\kose\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 23455 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\kose\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 38555 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\Users\kose\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 35336 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\kose\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 31639 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\kose\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 23455 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\Users\kose\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 38555 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import pandas as pd
import time
import matplotlib.pyplot as plt
while True:
    plt.figure()
    t1 = time.time()
    with pd.HDFStore("./data/sum2.hdf5") as store:
        temp = store.get("consequence")
    t2 = time.time()
    a,b,c = temp["time"].to_list(), temp["calc"].to_list(), temp["topix"].to_list()
    c = list(map(float, c))
    plt.plot(a,b)
    plt.plot(a,c)
    plt.ylim(1920, 1950)
    plt.show()
    #time.sleep(60)

# %%
temp["total"]

# %%
a
# Out:
# ['2022-05-12 19:54:35.863834',
#  '2022-05-12 19:54:36.024464',
#  '2022-05-12 19:54:36.160267',
#  '2022-05-12 19:54:36.296528',
#  '2022-05-12 19:54:36.431774',
#  '2022-05-12 19:54:36.567323',
#  '2022-05-12 19:54:36.703460',
#  '2022-05-12 19:54:36.842052',
#  '2022-05-12 19:54:36.977359',
#  '2022-05-12 19:54:37.121341',
#  '2022-05-12 19:54:37.262010',
#  '2022-05-12 19:54:37.396811',
#  '2022-05-12 19:54:37.531042',
#  '2022-05-12 19:55:11.727530',
#  '2022-05-12 19:55:11.863739',
#  '2022-05-12 19:55:12.002577',
#  '2022-05-12 19:55:12.139023',
#  '2022-05-12 19:55:12.274627',
#  '2022-05-12 19:55:12.407868',
#  '2022-05-17 09:03:13.976595',
#  '2022-05-17 09:03:14.265491',
#  '2022-05-17 09:03:14.543198',
#  '2022-05-17 09:03:14.837948',
#  '2022-05-17 09:03:15.136604',
#  '2022-05-17 09:03:15.448925',
#  '2022-05-17 09:03:15.726110',
#  '2022-05-17 09:03:16.000366',
#  '2022-05-17 09:03:16.291212',
#  '2022-05-17 09:03:16.672827',
#  '2022-05-17 09:03:16.982221',
#  '2022-05-17 09:03:17.538418',
#  '2022-05-17 09:03:17.842927',
#  '2022-05-17 09:03:18.143536',
#  '2022-05-17 09:03:18.445120',
#  '2022-05-17 09:03:18.728159',
#  '2022-05-17 09:03:19.016080',
#  '2022-05-17 09:03:19.302049',
#  '2022-05-17 09:03:19.609026',
#  '2022-05-17 09:03:19.909634',
#  '2022-05-17 09:03:20.207315',
#  '2022-05-17 09:03:20.499647',
#  '2022-05-17 09:03:20.826609',
#  '2022-05-17 09:03:21.126239',
#  '2022-05-17 09:03:21.433681',
#  '2022-05-17 09:03:21.710863',
#  '2022-05-17 09:03:22.004640',
#  '2022-05-17 09:03:22.311102',
#  '2022-05-17 09:03:22.630254',
#  '2022-05-17 09:03:22.948430',
#  '2022-05-17 09:03:23.268558',
#  '2022-05-17 09:03:23.565262',
#  '2022-05-17 09:03:28.132958',
#  '2022-05-17 09:03:28.433565',
#  '2022-05-17 09:03:28.737110',
#  '2022-05-17 09:03:29.051380',
#  '2022-05-17 09:03:29.342227',
#  '2022-05-17 09:03:29.636981',
#  '2022-05-17 09:03:29.945396',
#  '2022-05-17 09:03:30.222507',
#  '2022-05-17 09:03:30.508475',
#  '2022-05-17 09:03:30.797372',
#  '2022-05-17 09:03:31.121001',
#  '2022-05-17 09:03:31.441128',
#  '2022-05-17 09:03:31.738162',
#  '2022-05-17 09:03:32.029179',
#  '2022-05-17 09:03:32.333228',
#  '2022-05-17 09:03:32.631883',
#  '2022-05-17 09:03:32.921755',
